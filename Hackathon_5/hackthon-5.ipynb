# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Task 1

# %%
df = pd.read_csv(r'heart.csv')
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
df.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    int64
#  2   Sex         303 non-null    int64
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Chol        303 non-null    int64
#  6   Fbs         303 non-null    int64
#  7   RestECG     303 non-null    int64
#  8   MaxHR       303 non-null    int64
#  9   ExAng       303 non-null    int64
#  10  Oldpeak     303 non-null    float64
#  11  Slope       303 non-null    int64
#  12  Ca          299 non-null    float64
#  13  Thal        301 non-null    object
#  14  AHD         303 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 35.6+ KB

# %%
ahd_distribution = df['AHD'].value_counts()

ahd_distribution
# Out:
# AHD
# No     164
# Yes    139
# Name: count, dtype: int64

# %%
# Task 2

# %%
# Handle Missing Data

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
median_ca = df['Ca'].median()

# %%
df.fillna({'Ca': median_ca}, inplace=True)

# %% [markdown]
# mode_thal = df['Thal'].mode()[0]

# %%
df.fillna({'Thal':mode_thal}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.fillna({'Thal':mode_thal}, inplace=True)
#
# NameError: name 'mode_thal' is not defined

# %%
missing_values_count = df.isnull().sum()
missing_values_count
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            0
# Thal          2
# AHD           0
# dtype: int64

# %%
#Feature Engineering

# %%
unique_sex_values = df['Sex'].unique()

# %% [markdown]
# unique_restecg_values = df['RestECG'].unique()

# %%
df = pd.get_dummies(df, columns=['ChestPain'], prefix='ChestPain', drop_first=True)

# %%
df = pd.get_dummies(df, columns=['Thal'], prefix='Thal', drop_first=True)

# %%
df['AHD'] = df['AHD'].map({'No': 0, 'Yes': 1})

# %%
modified_df_head = df.head()
modified_df_head
# Out:
#    Unnamed: 0  Age  Sex  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0           1   63    1     145   233    1        2    150      0      2.3
# 1           2   67    1     160   286    0        2    108      1      1.5
# 2           3   67    1     120   229    0        2    129      1      2.6
# 3           4   37    1     130   250    0        0    187      0      3.5
# 4           5   41    0     130   204    0        2    172      0      1.4
#
#    Slope   Ca  AHD  ChestPain_nonanginal  ChestPain_nontypical  \
# 0      3  0.0    0                 False                 False
# 1      2  3.0    1                 False                 False
# 2      2  2.0    1                 False                 False
# 3      3  0.0    0                  True                 False
# 4      1  0.0    0                 False                  True
#
#    ChestPain_typical  Thal_normal  Thal_reversable
# 0               True        False            False
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
numerical = ['Age', 'RestBP', 'Chol', 'Fbs', 'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca']

# %%
scaler = StandardScaler()

# %%
df[numerical] = scaler.fit_transform(df[numerical])

# %%
scaled_df_head = df.head()

# %%
scaled_df_head
# Out:
#    Unnamed: 0  Age  Sex  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0           1   63    1     145   233    1        2    150      0      2.3
# 1           2   67    1     160   286    0        2    108      1      1.5
# 2           3   67    1     120   229    0        2    129      1      2.6
# 3           4   37    1     130   250    0        0    187      0      3.5
# 4           5   41    0     130   204    0        2    172      0      1.4
#
#    Slope   Ca  AHD  ChestPain_nonanginal  ChestPain_nontypical  \
# 0      3  0.0    0                 False                 False
# 1      2  3.0    1                 False                 False
# 2      2  2.0    1                 False                 False
# 3      3  0.0    0                  True                 False
# 4      1  0.0    0                 False                  True
#
#    ChestPain_typical  Thal_normal  Thal_reversable
# 0               True        False            False
# ...

# %%
df['exercise_inducedHeartStress'] = df['Oldpeak'] + df['Slope']
df['exercise_inducedHeartStress']
# Out:
# 0      5.3
# 1      3.5
# 2      4.6
# 3      6.5
# 4      2.4
#       ...
# 298    3.2
# 299    5.4
# 300    3.2
# 301    2.0
# 302    1.0
# Name: exercise_inducedHeartStress, Length: 303, dtype: float64

# %%
# Task 3

# %%
key_numerical_feature = ['Age', 'Chol', 'MaxHR']
plt.figure(figsize=(15, 5))
for i, feature in enumerate(key_numerical_feature):
    plt.subplot(1, 3, i + 1)
    sns.histplot(df[feature], kde=True)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')

plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 plt.figure(figsize=(15, 5))
# ----> 2 for i, feature in enumerate(key_numerical_feature):
#       3     plt.subplot(1, 3, i + 1)
#       4     sns.histplot(df[feature], kde=True)
#
# NameError: name 'key_numerical_feature' is not defined

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='AHD', data=df)
plt.title('Distribution of Target Variable')
plt.xlabel('AHD')
plt.ylabel('Count')
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'RestBP', 'Chol', 'Fbs', 'RestECG', 'MaxHR',
#        'ExAng', 'Oldpeak', 'Slope', 'Ca', 'AHD', 'ChestPain_nonanginal',
#        'ChestPain_nontypical', 'ChestPain_typical', 'Thal_normal',
#        'Thal_reversable', 'ExerciseInducedHeartStress',
#        'exercise_inducedHeartStress'],
#       dtype='object')

# %%
categorical_features = ['Sex', 'ChestPain_nonanginal', 'ChestPain_nontypical', 'ChestPain_typical', 'Fbs', 'ExAng']


plt.figure(figsize=(15, 5))
for i, feature in enumerate(categorical_features):
    plt.subplot(1, len(categorical_features), i + 1)
    sns.countplot(x=feature, hue='AHD', data=df)
    plt.title(f'Relationship between Target  and {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
numerical_features_2 = ['Age', 'Chol', 'MaxHR']
plt.figure(figsize=(15, 5))
for i, feature in enumerate(numerical_features_2):
    plt.subplot(1, len(numerical_features_2), i + 1)
    sns.boxplot(x='AHD', y=feature, data=df)
    plt.title(f'Relationship between Target and {feature}')
    plt.xlabel('AHD (0=No, 1=Yes)')
    plt.ylabel(feature)
plt.tight_layout()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 plt.figure(figsize=(15, 5))
# ----> 2 for i, feature in enumerate(numerical_features_2):
#       3     plt.subplot(1, len(numerical_features_2), i + 1)
#       4     sns.boxplot(x='AHD', y=feature, data=df)
#
# NameError: name 'numerical_features_2' is not defined

# %%
numerical_df = df.select_dtypes(include=['number'])
correlation_matrix = numerical_df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Features')
plt.tight_layout()
plt.show()

# %%
features_for_correlation = ['Chol', 'Age', 'RestBP']
correlation_subset = df[features_for_correlation].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_subset, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Cholesterol, Age, and Resting Blood Pressure')
plt.tight_layout()
plt.show()

# %%
# Task 4

# %%
gender_mapping = {1: 'M', 0: 'F'}
survival_by_gender = df.groupby('Sex')['AHD'].value_counts(normalize=True) * 100
survival_by_gender.index = survival_by_gender.index.set_levels([survival_by_gender.index.levels[0].map(gender_mapping), survival_by_gender.index.levels[1]])
survival_by_gender
# Out:
# Sex  AHD
# F    0      74.226804
#      1      25.773196
# M    1      55.339806
#      0      44.660194
# Name: proportion, dtype: float64

# %%
survival_rate_gender = df.groupby('Sex')['AHD'].agg(lambda x: (x == 0).sum() / len(x) * 100)
survival_rate_gender.index = survival_rate_gender.index.map(gender_mapping)
survival_rate_gender
# Out:
# Sex
# F    74.226804
# M    44.660194
# Name: AHD, dtype: float64

# %%
survival_by_chest_pain = df.groupby(['ChestPain_nonanginal', 'ChestPain_nontypical', 'ChestPain_typical'])['AHD'].value_counts(normalize=True) * 100
survival_rate_chest_pain = df.groupby(['ChestPain_nonanginal', 'ChestPain_nontypical', 'ChestPain_typical'])['AHD'].agg(lambda x: (x == 0).sum() / len(x) * 100)
survival_rate_chest_pain
# Out:
# ChestPain_nonanginal  ChestPain_nontypical  ChestPain_typical
# False                 False                 False                27.083333
#                                             True                 69.565217
#                       True                  False                82.000000
# True                  False                 False                79.069767
# Name: AHD, dtype: float64

# %%
bins = [df['MaxHR'].min() - 1, 100, 120, 140, 160, 180, df['MaxHR'].max() + 1]
labels = ['<100', '101-120', '121-140', '141-160', '161-180', '>180']
df['MaxHR_Bin'] = pd.cut(df['MaxHR'], bins=bins, labels=labels, right=False)
survival_by_maxhr = df.groupby('MaxHR_Bin',observed=False)['AHD'].value_counts(normalize=True) * 100
survival_by_maxhr
# Out:
# MaxHR_Bin  AHD
# <100       1      87.500000
#            0      12.500000
# 101-120    1      76.923077
#            0      23.076923
# 121-140    1      66.666667
#            0      33.333333
# 141-160    0      51.515152
#            1      48.484848
# 161-180    0      72.727273
#            1      27.272727
# >180       0      85.000000
#            1      15.000000
# Name: proportion, dtype: float64

# %%
average_cholesterol_by_ahd = df.groupby('AHD')['Chol'].mean()
average_cholesterol_by_ahd
# Out:
# AHD
# 0    242.640244
# 1    251.474820
# Name: Chol, dtype: float64

# %%
average_cholesterol_by_chest_pain_and_ahd = df.groupby(['ChestPain_nonanginal', 'ChestPain_nontypical', 'ChestPain_typical', 'AHD'])['Chol'].mean()
average_cholesterol_by_chest_pain_and_ahd
# Out:
# ChestPain_nonanginal  ChestPain_nontypical  ChestPain_typical  AHD
# False                 False                 False              0      245.333333
#                                                                1      252.438095
#                                             True               0      229.875000
#                                                                1      253.714286
#                       True                  False              0      240.682927
#                                                                1      263.444444
# True                  False                 False              0      245.279412
#                                                                1      239.000000
# Name: Chol, dtype: float64

# %%
average_cholesterol_by_chest_pain_and_ahd
# Out:
# ChestPain_nonanginal  ChestPain_nontypical  ChestPain_typical  AHD
# False                 False                 False              0      245.333333
#                                                                1      252.438095
#                                             True               0      229.875000
#                                                                1      253.714286
#                       True                  False              0      240.682927
#                                                                1      263.444444
# True                  False                 False              0      245.279412
#                                                                1      239.000000
# Name: Chol, dtype: float64

# %%
# Task 5

# %%
average_age_by_ahd = df.groupby('AHD')['Age'].mean()
average_age_by_ahd
# Out:
# AHD
# 0    52.585366
# 1    56.625899
# Name: Age, dtype: float64

# %%
average_cholesterol_by_ahd
# Out:
# AHD
# 0    242.640244
# 1    251.474820
# Name: Chol, dtype: float64

# %%
survival_by_maxhr
# Out:
# MaxHR_Bin  AHD
# <100       1      87.500000
#            0      12.500000
# 101-120    1      76.923077
#            0      23.076923
# 121-140    1      66.666667
#            0      33.333333
# 141-160    0      51.515152
#            1      48.484848
# 161-180    0      72.727273
#            1      27.272727
# >180       0      85.000000
#            1      15.000000
# Name: proportion, dtype: float64

# %%
survival_rate_chest_pain
# Out:
# ChestPain_nonanginal  ChestPain_nontypical  ChestPain_typical
# False                 False                 False                27.083333
#                                             True                 69.565217
#                       True                  False                82.000000
# True                  False                 False                79.069767
# Name: AHD, dtype: float64

# %%
survival_rate_gender
# Out:
# Sex
# F    74.226804
# M    44.660194
# Name: AHD, dtype: float64

# %%
bins = [df['MaxHR'].min() - 1, 100, 120, 140, 160, 180, df['MaxHR'].max() + 1]
labels = ['<100', '101-120', '121-140', '141-160', '161-180', '>180']
df['MaxHR_Bin'] = pd.cut(df['MaxHR'], bins=bins, labels=labels, right=False)
survival_by_maxhr = df.groupby('MaxHR_Bin',observed=False)['AHD'].value_counts(normalize=True) * 100
survival_by_maxhr
# Out:
# MaxHR_Bin  AHD
# <100       1      87.500000
#            0      12.500000
# 101-120    1      76.923077
#            0      23.076923
# 121-140    1      66.666667
#            0      33.333333
# 141-160    0      51.515152
#            1      48.484848
# 161-180    0      72.727273
#            1      27.272727
# >180       0      85.000000
#            1      15.000000
# Name: proportion, dtype: float64
